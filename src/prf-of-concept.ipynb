# %% [markdown]
# Modified from the [NVFlare Hello PyTorch example](https://github.com/NVIDIA/NVFlare/tree/main/examples/hello-world/hello-pt)

# %% [markdown]
# ## Run an NVFlare Job
# Now that we have defined the FedAvg controller to run our federated compute workflow on the FL server, and our client training script to receive the global models, run local training, and send the results back to the FL server, we can put everything together using NVFlare's Job API.

# %% [markdown]
# #### 2. Define a FedJob Recipe

# %%
from server.model import FusionNet

from nvflare.app_opt.pt.recipes.fedavg import FedAvgRecipe
from nvflare.recipe import SimEnv
from nvflare.recipe import add_experiment_tracking
import torch 
n_clients = 2
num_rounds = 4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model = FusionNet().to(device)

recipe = FedAvgRecipe(
    name="MEM_SAN_FedCollab", # MEM - Memphis, SAN - San Diego
    min_clients=n_clients,
    num_rounds=num_rounds,
    initial_model=model,
    train_script="multi-client-sim.py",
)

# %% [markdown]
# #### 3. Add experiment tracking

# %%
add_experiment_tracking(recipe, tracking_type="tensorboard")

# %% [markdown]
# #### 4. Run Job
# Here, we run the job in a simulation environment.

# %%
env = SimEnv(num_clients=n_clients)
run = recipe.execute(env)
print()
print("Job Status is:", run.get_status())
print("Result can be found in :", run.get_result())
print()
# Out:
# 2026-01-09 02:11:20,433 - INFO - model selection weights control: {}
# 2026-01-09 02:11:21,029 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events`
# 2026-01-09 02:11:21,029 - INFO - Tensorboard records can be found in /tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/tmp/nvflare/simulation/MEM_SAN_FedCollab/server/simulate_job/tb_events`
# 2026-01-09 02:11:21,029 - INFO - Initializing ScatterAndGather workflow for Federated Averaging.
# 2026-01-09 02:11:21,029 - INFO - Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2026-01-09 02:11:21,030 - INFO - Beginning ScatterAndGather training phase.
# 2026-01-09 02:11:21,030 - INFO - Round 0 started.
# 2026-01-09 02:11:24,686 - INFO - start task run() with full path: /tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py
# 2026-01-09 02:11:24,686 - INFO - start task run() with full path: /tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py
# 2026-01-09 02:11:24,804 - INFO - --- site-1: Memphis ---
# 2026-01-09 02:11:24,804 - INFO - --- site-2: San Diego ---
# 2026-01-09 02:11:24,967 - INFO - execute for task (train)
# 2026-01-09 02:11:24,967 - INFO - send data to peer
# 2026-01-09 02:11:24,967 - INFO - sending payload to peer
# 2026-01-09 02:11:24,967 - INFO - Waiting for result from peer
# 2026-01-09 02:11:24,982 - INFO - execute for task (train)
# 2026-01-09 02:11:24,982 - INFO - send data to peer
# 2026-01-09 02:11:24,982 - INFO - sending payload to peer
# 2026-01-09 02:11:24,982 - INFO - Waiting for result from peer
# 2026-01-09 02:11:25,330 - ERROR - Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 68, in main
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#     for data in data_loader:
#                 ^^^^^^^^^^^
# NameError: name 'data_loader' is not defined
#
# 2026-01-09 02:11:25,330 - ERROR - Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 68, in main
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#     for data in data_loader:
#                 ^^^^^^^^^^^
# NameError: name 'data_loader' is not defined
#
# 2026-01-09 02:11:25,330 - ERROR - fire abort event
# 2026-01-09 02:11:25,330 - ERROR - fire abort event
# 2026-01-09 02:11:25,331 - ERROR - ask to abort job: reason: '/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py' is aborted, Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 68, in main
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#     for data in data_loader:
#                 ^^^^^^^^^^^
# NameError: name 'data_loader' is not defined
#
# 2026-01-09 02:11:25,331 - ERROR - ask to abort job: reason: '/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py' is aborted, Traceback (most recent call last):
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 68, in main
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#     for data in data_loader:
#                 ^^^^^^^^^^^
# NameError: name 'data_loader' is not defined
#
# 2026-01-09 02:11:25,472 - ERROR - ask to abort job: reason: train' is aborted, abort_signal_triggered
# 2026-01-09 02:11:25,484 - ERROR - Aborting current RUN due to FATAL_SYSTEM_ERROR received: Result from site-1 is bad, error code: TASK_ABORTED. ScatterAndGather exiting at round 0.
# 2026-01-09 02:11:25,485 - ERROR - ask to abort job: reason: train' is aborted, abort_signal_triggered
# Exception in thread Thread-2 (run):
# Traceback (most recent call last):
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# Exception in thread Thread-2 (run):
# Traceback (most recent call last):
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1012, in run
#     self.run()
#   File "/Users/tyleryang/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 71, in run
#     raise e
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     self._target(*self._args, **self._kwargs)
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 71, in run
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 90, in <module>
#     raise e
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/.venv/lib/python3.12/site-packages/nvflare/app_common/executors/task_script_runner.py", line 54, in run
#     main()
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-1/simulate_job/app_site-1/custom/multi-client-sim.py", line 68, in main
#     runpy.run_path(self.script_full_path, run_name="__main__")
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 90, in <module>
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^    main()
# ^^^^^^^^^^^^^
#   File "/tmp/nvflare/simulation/MEM_SAN_FedCollab/site-2/simulate_job/app_site-2/custom/multi-client-sim.py", line 68, in main
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#     accuracy = evaluate(model, testCDloader, testRNAloader, device)
#        for data in data_loader:
#            ^ ^ ^ ^  ^^^^^^ ^     ^ ^^^^^^^^  ^  ^^^^^^^^^^^^^^^^^^
# ^^^^^^^NameError: name 'data_loader' is not defined^^^^^^^^^^^^^^^^^
#   File "/Users/tyleryang/Developer/CMU-NVIDIA-Hackathon/Knowledge_Structures_Multimodal/src/clients/evaluate.py", line 43, in evaluate
#
#     for data in data_loader:
#                 ^^^^^^^^^^^
# NameError: name 'data_loader' is not defined
# 2026-01-09 02:11:25,541 - INFO - Abort signal received. Exiting at round 0.
# 2026-01-09 02:11:27,555 - WARNING - ask to stop job: reason: END_RUN received
# 2026-01-09 02:11:27,555 - WARNING - ask to stop job: reason: END_RUN received
#
# Note, get_status returns None in SimEnv. The simulation logs can be found at /tmp/nvflare/simulation/MEM_SAN_FedCollab
# Job Status is: None
# Result can be found in : /tmp/nvflare/simulation/MEM_SAN_FedCollab

# %% [markdown]
# #### 5. Visualize the Training
# You can use TensorBoard to show the experiment tracking curves by running
#
# ```bash
# tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab
# ```
# in another terminal or directly show the training curves in the next notebook cell.

# %%
# asked Holger, logs are in server/simulate_job/tb_events
# they were empty because of the 2000 datapt condition.
# %load_ext tensorboard
# %tensorboard --bind_all --logdir /tmp/nvflare/simulation/MEM_SAN_FedCollab # also had this stuck as hello-pt
